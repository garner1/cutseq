# %%
# %reload_ext autoreload
# %autoreload 2
from module import *

'''groupby can be {none,23-24-reduced}:'''
groupby = 'none'
resolution = 10000000
RC_threshold = 0

# %%
positionlist, chromlist, border = structure_genome(resolution)

# %%
exp = 'xz_13' 
X_13,indexExp_list,index0_list,index1_list,index2_list,index3_list = load_data(exp,resolution,positionlist)
X_df_13, X_red_df_13, X_13 = load_RCdf(X_13,exp,chromlist,positionlist,groupby,RC_threshold,indexExp_list,index0_list,index1_list,index2_list,index3_list)

# %%
exp = 'xz_14' 
X_14,indexExp_list,index0_list, index1_list, index2_list, index3_list = load_data(exp,resolution,positionlist)
X_df_14, X_red_df_14, X_14 = load_RCdf(X_14,exp,chromlist,positionlist,groupby,RC_threshold,indexExp_list,index0_list,index1_list,index2_list,index3_list)

# %%
exp = 'xz_19' 
X_19, indexExp_list,index0_list, index1_list, index2_list, index3_list = load_data(exp,resolution,positionlist)
X_df_19, X_red_df_19, X_19 = load_RCdf(X_19,exp,chromlist,positionlist,groupby,RC_threshold,indexExp_list,index0_list,index1_list,index2_list,index3_list)

# %%
exp = 'xz_20' 
X_20, indexExp_list,index0_list, index1_list, index2_list, index3_list = load_data(exp,resolution,positionlist)
X_df_20, X_red_df_20, X_20 = load_RCdf(X_20,exp,chromlist,positionlist,groupby,RC_threshold,indexExp_list,index0_list,index1_list,index2_list,index3_list)

# %%
exp = 'xz_21' 
X_21, indexExp_list,index0_list, index1_list, index2_list, index3_list = load_data(exp,resolution,positionlist)
X_df_21, X_red_df_21, X_21 = load_RCdf(X_21,exp,chromlist,positionlist,groupby,RC_threshold,indexExp_list,index0_list,index1_list,index2_list,index3_list)

# %%
exp = 'xz_22' 
X_22, indexExp_list,index0_list, index1_list, index2_list, index3_list = load_data(exp,resolution,positionlist)
X_df_22, X_red_df_22, X_22 = load_RCdf(X_22,exp,chromlist,positionlist,groupby,RC_threshold,indexExp_list,index0_list,index1_list,index2_list,index3_list)

# %%
exp = 'xz_23' 
X_23, indexExp_list,index0_list, index1_list, index2_list, index3_list = load_data(exp,resolution,positionlist)
X_df_23, X_red_df_23, X_23 = load_RCdf(X_23,exp,chromlist,positionlist,groupby,RC_threshold,indexExp_list,index0_list,index1_list,index2_list,index3_list)

# %%
exp = 'xz_24' 
X_24, indexExp_list,index0_list, index1_list, index2_list, index3_list = load_data(exp,resolution,positionlist)
X_df_24, X_red_df_24, X_24 = load_RCdf(X_24,exp,chromlist,positionlist,groupby,RC_threshold,indexExp_list,index0_list,index1_list,index2_list,index3_list)

# %%
exp = 'xz_23_24' 
X_2324, indexExp_list,index0_list, index1_list, index2_list, index3_list = load_data(exp,resolution,positionlist)
X_df_2324, X_red_df_2324, X_2324 = load_RCdf(X_2324,exp,chromlist,positionlist,groupby,RC_threshold,indexExp_list,index0_list,index1_list,index2_list,index3_list)

# %%
frames_all = [X_df_13,X_df_14,X_df_19,X_df_20,X_df_21,X_df_21,X_df_22,X_df_2324]
sample_all = pd.concat(frames_all)
sample_1920 = pd.concat([X_df_19,X_df_20])
sample_2122 = pd.concat([X_df_21,X_df_22])
sample_13 = X_df_13
sample_14 = X_df_14
sample_2324 = X_df_2324

# %%
data = sample_all
data = data.groupby(level=['row','column']).mean()
df = data
RC_threshold = 1000
data = data.loc[~(data.sum(axis=1)<RC_threshold)]
data = new_normalize(data)

# %%
'''Construct the average sample profile'''
data = sample_all
data = data.mean()
data = data.to_frame().transpose()
df = data

# sns.set_style("darkgrid")
# plt.plot(np.asarray(data))
# plt.show()

sns.heatmap(data)
plt.show()

# %%
# ?data

# %%
'''Hierarchical cluster'''
import matplotlib.pyplot as plt
import seaborn as sns

method = 'average'
metric = 'euclidean'

xticklabels=[]
g = sns.clustermap(new,method=method,metric=metric,col_cluster=False,linewidths=0.0,cmap='Greys')

plt.title('Res_10M_Threshold_'+str(RC_threshold))

plt.setp(g.ax_heatmap.yaxis.get_majorticklabels(), rotation=0)
plt.setp(g.ax_heatmap.xaxis.get_majorticklabels(), rotation=90)

plt.setp(g.ax_heatmap.set_xticks(border))

for i in border:
    plt.setp(g.ax_heatmap.axvline(i,c="r",lw=0.1))

# g.savefig('Clustering_XZ2324_Threshold_'+str(RC_threshold)+'.png')

from IPython.display import clear_output
clear_output()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

index = ['A','B','C','D','E','F','G','H','I','J']
columns = ['1','2','3','4','5','6','7']
totalRC_df = pd.DataFrame(0,index=index, columns=columns)
totalRC = []

for i in df.index:
    totalRC.append( df.ix[i].sum(axis=0) )
for i in range(len(df.index.values)):
    totalRC_df.ix[df.index.values[i][0],df.index.values[i][1]] = totalRC[i]

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure()
g = sns.heatmap(totalRC_df,square=False, annot=True, cmap="Blues", cbar=True)
# plt.title('RC  for '+exp+' and threshold:'+str(RC_threshold))

plt.show()
# g.figure.savefig('RC_'+exp+'.png')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-116-19f3155b0eb9> in <module>()
#      10     totalRC.append( df.ix[i].sum(axis=0) )
#      11 for i in range(len(df.index.values)):
# ---> 12     totalRC_df.ix[df.index.values[i][0],df.index.values[i][1]] = totalRC[i]
#      13
#      14 import matplotlib.pyplot as plt
#
# /home/garner1/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in __setitem__(self, key, value)
#     114
#     115     def __setitem__(self, key, value):
# --> 116         indexer = self._get_setitem_indexer(key)
#     117         self._setitem_with_indexer(indexer, value)
#     118
#
# /home/garner1/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _get_setitem_indexer(self, key)
#     104
#     105         if isinstance(key, tuple) and not self.ndim < len(key):
# ...

# %%
sample_tumorANDstroma.groupby(level=['row','column']).mean()
# Out:
# chromosome        chr1                                                  \
# bin                0           1           2           3           4
# row column
# A   1        14.000000   15.666667   15.333333   15.000000   33.000000
#     2       112.666667  119.000000  123.333333  134.666667  211.000000
#     3         0.000000    0.000000    0.666667    0.000000    0.666667
#     4       129.666667  143.000000  170.333333  153.333333  197.333333
# B   1         0.333333    0.333333    0.000000    0.333333    0.333333
#     2         1.666667    1.000000    0.666667    0.666667    3.333333
#     3         0.000000    0.000000    0.000000    0.000000    0.000000
#     4         3.000000    1.000000    2.333333    4.666667    7.000000
# C   1         0.000000    0.000000    0.000000    0.000000    0.666667
#     2         0.000000    0.000000    0.000000    0.000000    1.000000
#     4         0.000000    0.333333    0.000000    0.000000    1.000000
# ...
